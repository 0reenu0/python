# %% [markdown]
# #### donut chart

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# In most cases, a donut chart can replace a pie chart since their use-cases are not vastly different. A donut chart typically shows the proportions of categorical data where the size of each piece of the donut communicates the proportion of each category.
#
# The simplest example could be the extension of an elementary math problem. Assuming we have twenty apples, ten bananas, fifteen oranges, and seven pineapples, which fruit has the highest proportion in the basket? The donut with the longest arc represents the fruit that is present, as it happens, in abundance.
#
# But to say that these are the only uses of a donut chart would be too simplistic. In general, a donut chart occupies far less space than its pie counterpart, which makes it ideal for placing in dashboards that already have a lot of information to process, as well as in business reports where data needs to be visualized simultaneously to draw the best insights.
#
# For example, a donut chart of electronics sales for a company in 2020 can be placed inside a donut chart of electronics sales in 2021. Doing so allows one to place the data table right next to the chart and communicate more information than would be possible by placing two charts next to each other, and their corresponding data table underneath.

# %% [markdown]
# when to not use:
# As with most other forms of data representation, a donut chart can become cluttered with too many segments.
#
# A donut chart is not the best format to use when negative values need to be represented.
#
# If changes over time need to be tracked, a donut chart is not the best chart option to use, because unlike a bubble chart’s tracker, it cannot retain the information it represents over a period of time. For example, a donut chart for annual expenditure continues to change as adjustments are made to its data source, without retaining any of the information from before the change was made. As a result, there is no way for the reader to see how expenditure has grown over time.

# %% [markdown]
# Alternatives to donut charts
# A pie chart can replace a donut chart in nearly every application where the specific benefit of a donut chart—comparing areas as absolutes—is not a requirement.
#
# Apart from a pie chart, the data in a donut chart can also be represented in other graph types:
#
# Percentage bar chart
# This serves nearly the same purpose as a donut chart. However, it can also be used when there is limited space, or when the total of all segments does not add up to 100 percent. For example, a percentage bar chart can be used to compare greenhouse gas emissions in 2010 with emissions in 2020, which would be higher.
#
# Treemap
# A treemap offers a stunning visual tool that can be used to add more information about each of the segments. It often looks like a stack of blocks, and each block can then be used for adding a description with the data.
#
# A waffle chart
# This replaces a donut chart in cases where the data is larger and easier to comprehend when several squares are present as a visual aid. For example, it could be used to represent the number of people under age 20 per million people in any given year.
#
# For those who wish to experiment with more interesting representations of data than using a plain table, a donut chart is a great starting point. However, it does come with its own set of limitations and must be used only when it provides visual benefit. For data that is segmented into very tiny bits or that often flows into negative values, other chart types such as a bar chart may be more ideal.

# %%
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]

# %%
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# %% [markdown]
# ### stacked bar plot

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.DataFrame({
    'Category': ['Apples', 'Bananas', 'Oranges', 'Apples', 'Bananas', 'Oranges'],
    'Group1': [5, 3, 4, 2, 6, 1],
    'Group2': [3, 2, 5, 1, 4, 3],
    'Group3': [2, 4, 1, 3, 2, 5]
})

# %%
fig,ax=plt.subplots()
bar_width=0.35

bars1=ax.bar(df['Category'],df['Group1'],bar_width)
bars2=ax.bar(df['Category'],df['Group2'],bar_width,bottom=df['Group1'])
bars2=ax.bar(df['Category'],df['Group3'],bar_width,bottom=df['Group2'])

ax.set_xlabel('Category')
ax.set_ylabel('Values')
ax.set_title('Stacked Bar Plot')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.DataFrame({
    'Category': ['Apples', 'Bananas', 'Oranges', 'Apples', 'Bananas', 'Oranges'],
    'Group1': [5, 3, 4, 2, 6, 1],
    'Group2': [3, 2, 5, 1, 4, 3],
    'Group3': [2, 4, 1, 3, 2, 5]
})

# %%
sns.set()
sns.barplot(x='Category', y='Group1', data=df,hue='Category', palette='Blues',legend=False)
sns.barplot(x='Category',y='Group2', data=df, hue='Category', bottom='Group1', palette='Oranges', legend=False)
sns.barplot(x='Category',y='Group3', data=df, hue='Category', bottom='Group2', palette='Reds', legend=False)

plt.xlabel('Category')
plt.ylabel('Values')
plt.title('Stacked Bar Plot')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generate sample data
df = pd.DataFrame({
    'Date': ['2022-08-01', '2022-09-01', '2022-10-01', '2022-08-01', '2022-09-01', '2022-10-01', '2022-08-01', '2022-09-01', '2022-10-01'],
    'Type': ['Type1', 'Type1', 'Type1', 'Type2', 'Type2', 'Type2', 'Type3', 'Type3', 'Type3'],
    'Value': [5000, 5500, 6000, 50000, 55000, 60000, 20000, 18000, 19000]
})

# Create a stacked bar plot
ax = sns.barplot(x='Date', y='Value', hue='Type', data=df, palette='viridis')

# Set the legend title
ax.legend(title='Type')

# Show the plot
plt.show()

# %% [markdown]
# ### Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

data=np.random.randn(1000)

plt.hist(data,bins=30, density=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df= sns.load_dataset("iris")
df.info()
sns.histplot(data=df,x="sepal_width",kde=True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### Box plot

# %% [markdown]
#  key differences between using Matplotlib and Seaborn for creating box plots:
#
# ##### Syntax: Seaborn’s boxplot() function is more concise and easier to use than Matplotlib’s boxplot() function.
# ##### Customization: Seaborn provides more customization options, such as changing the color palette, adding a legend, and modifying the appearance of the box plot.
# ######
# Integration: Seaborn is built on top of Matplotlib, so you can use Matplotlib’s functions and customization options in combination with Seaborn.
# ######
#  Default styles: Seaborn provides default styles and color palettes that make statistical plots more attractive.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data=np.random.randn(100)

# %%
plt.boxplot(data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
dtaa=np.random.randn(100)

# %%
sns.boxplot(dtaa)
plt.show()

# %% [markdown]
# ### Pie chart

# %%
import matplotlib.pyplot as plt
data=[30,20,50]
labels=['apples','oranges','eggs']

# %%
fig,ax=plt.subplots()
ax.pie(data,labels=labels,autopct='%1.1f%%',startangle=90)
ax.axis('equal')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=[30,20,50]
labels=['apples','oranges','eggs']

# %%
sns.set_style("whitegrid")

# %%
plt.figure(figsize=(3,3))
plt.pie(data,labels=labels)
plt.show()

# %% [markdown]
# ### exploded pie chart

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y=np.array([35,25,25,15])
mylabels=["Tomatoes","Apples",'Eggs','Mangoes']
myexplode=[0.2,0,0,0]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.show()

# %% [markdown]
# ### plotly
# ###### it is a Python graphing library that makes interactive, publication-quality graphs. It has a wide range of features, including support for pie charts. Here’s a simple example of how to create a pie chart using plotly:

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

labels = ["Asia", "Europe", "Africa", "Americas", "Oceania"]

fig=make_subplots(1,2,specs=[[{'type':'domain'},{'type':'domain'}]], subplot_titles=['1980','2007'])
fig.add_trace(go.Pie(labels=labels,values=[4,7,1,7,0.5],scalegroup='one',name='World GDP 1980'),1,1)
fig.add_trace(go.Pie(labels=labels,values=[21,15,3,19,1],scalegroup='one',name='World GDP 2007'),1,2)
fig.update_layout(title_text='World GDP')
fig.show()
# Out:
# <div>                            <div id="c39ae773-4988-4f5a-9346-65e6563813fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c39ae773-4988-4f5a-9346-65e6563813fc")) {                    Plotly.newPlot(                        "c39ae773-4988-4f5a-9346-65e6563813fc",                        [{"labels":["Asia","Europe","Africa","Americas","Oceania"],"name":"World GDP 1980","scalegroup":"one","values":[4,7,1,7,0.5],"type":"pie","domain":{"x":[0.0,0.45],"y":[0.0,1.0]}},{"labels":["Asia","Europe","Africa","Americas","Oceania"],"name":"World GDP 2007","scalegroup":"one","values":[21,15,3,19,1],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"
# ...

# %% [markdown]
# ### Relative Stacked BAR PLOT

# %% [markdown]
# #### NOTE: Seaborn doesn’t support stacked bar plots directly, but you can create a similar plot using matplotlib’s bar function and then customize the plot using seaborn’s functions.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
categories=['A','B','C']
values1=[10,20,30]
values2=[20,30,40]

fig,ax=plt.subplots()

bar_width=0.35
bar1=ax.bar(categories,values1,bar_width,label='Category 1')
bar2=ax.bar(categories, values2,bar_width,bottom=values1,label='Category 2')

ax.set_xticks(np.arange(len(categories)))
ax.set_xticklabels(categories)

ax.set_ylabel('Relative Values')
ax.set_ylim(0,60)

ax.legend()

# Customize the plot using seaborn - styling using seaborn for a darn grid background
sns.set_style('darkgrid')
sns.despine(trim=True)

plt.show()

# %% [markdown]
# ### Stacked area plots

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x=np.arange(5)
y1=[3, 2, 3, 9, 10]
y2=[5, 5, 6, 12, 14]
y3=[20, 42, 28, 62, 81]

plt.stackplot(x,y1,y2,y3,labels=['sales','signups','visits'],colors=['red', 'green', 'blue'])

plt.title('Stacked Area Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# #### note:seaborn, it does not have a built-in function for creating stacked area plots. However, you can use the areaplot function from pandas or the plot function from matplotlib to create a stacked area plot and then customize it using seaborn’s functions

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the stacked area plot using matplotlib
plt.stackplot(x, y1, y2, y3, labels=['sales', 'signups', 'visits'])

# Set the style of the plot using seaborn
sns.set_style("whitegrid")

# Show the plot
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
import matplotlib.pyplot as plt

# %%
dataset=sns.load_dataset('iris')
x_axis=dataset['petal_length']
y_axis=dataset['petal_width']

plt.xlabel("Petal length")
plt.ylabel("Petal width")
plt.title("Petal length vs petal width")
plt.scatter(x_axis,y_axis,c='m')
plt.show()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.scatterplot(x='petal_length',y='petal_width',hue='species',data=dataset)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# ### bar plots

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3]
y=[1,5,3]

plt.bar(x,y)
plt.show()

# %%
import seaborn as sns
x=[1,2,3]
y=[1,5,3]
sns.barplot(x=x,y=y)
plt.show()

# %%
tips_df=sns.load_dataset("tips")
sns.barplot(x="sex",y="total_bill",data=tips_df,err_kws={'linewidth': 1,'color': 'red'})
plt.show()

# %%
sns.barplot(x="sex",y="total_bill",hue="sex",data=tips_df,err_kws={'linewidth': 1,'color': 'red'})
plt.show()

# %% [markdown]
# ## Continuous vs discrete Plot
# When it comes to plotting data, it’s essential to understand the difference between continuous and discrete data. Continuous data is a type of numerical data that refers to the unspecified number of possible measurements between two presumed points. This type of data is often represented by a line graph or a continuous plot. On the other hand, discrete data is a type of numerical data that is countable in a finite amount of time. This type of data is often represented by a bar graph, pie chart, or a scatter plot.
#
# Here are some key differences between continuous and discrete data:
#
# Continuous data can take on any value within a certain range, while discrete data can only take on specific values.
# Continuous data is often measured on a scale, such as temperature or time, while discrete data is often measured in counts or frequencies.
# Continuous data can be represented by a line graph, while discrete data is often represented by a bar graph or a scatter plot.
# In the context of a plot, continuous data is often used to represent variables that can take on any value within a certain range, such as temperature or time. Discrete data, on the other hand, is often used to represent variables that can only take on specific values, such as the number of people in a room or the number of items in a basket.
#
# Here’s an example of how to tell the difference between discrete and continuous data in a plot:
#
# If you’re plotting the number of people in a room, you would use a bar graph to represent the discrete data.
# If you’re plotting the temperature over time, you would use a line graph to represent the continuous data.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Continuous data
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.title('Continuous Data')
plt.show()

# Discrete data
x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.bar(x, y)
plt.xlabel('Item')
plt.ylabel('Count')
plt.title('Discrete Data')
plt.show()

# %% [markdown]
#  Line PLOT

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[2,4,6,8,10]

plt.plot(tips_df['total_bill'],tips_df['tip'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x='total_bill', y='tip',data=tips_df)
plt.show()

# %% [markdown]
# When to use each fo rline charts
#
# Use Matplotlib when:
# You need fine-grained control over the plot’s appearance.
# You’re working with a small dataset.
# You want to create a custom plot that’s not supported by Seaborn.
# Use Seaborn when:
# You’re working with a large dataset and want to create a high-level summary plot.
# You want to create a visually appealing plot with minimal code.
# You’re working with statistical data and want to create informative plots

# %% [markdown]
# LINE CHART COVID DATA

# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv('covid-19-data.csv')
df['date']=pd.to_datettime(df['date'])

plt.plot(df['date'],df['cases'])

plt.title('Covid-19 cases over time')
plt.xlabel('DATE')
plt.ylabel('Number of Cases')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 4
#       1 import matplotlib.pyplot as plt
#       2 import pandas as pd
# ----> 4 df=pd.read_csv('covid-19-data.csv')
#       5 df['date']=pd.to_datettime(df['date'])
#       7 plt.plot(df['date'],df['cases'])
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv('covid-19-data.csv')
df['date']=pd.to_datettime(df['date'])

sns.lineplot(x='date', y='cases', data=df)

plt.title('Covid-19 cases over time')
plt.xlabel('DATE')
plt.ylabel('Number of Cases')
plt.show()
